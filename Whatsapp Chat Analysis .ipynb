# %% [markdown]
# # Whatsapp Chat Analysis

# %%
import re
import pandas as pd

# %%
f = open('WhatsApp Chat with CS Squad Fall 21 to 25.txt' , 'r' , encoding='utf-8')

# %%
data = f.read()

# %%
print(type(data))
# Out:
# <class 'str'>

# %%
len(data)
# Out:
# 376839

# %%
len(data)
# Out:
# 376839

# %%
#pattern = '\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}\s-\s'

# %%
pattren = '\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}\s(?:AM|PM)\s-\s'

# %%
#pattern = r'\d{1,2}/\d{1,2}/\d{2,4}, \d{1,2}:\d{2} [APM]{2} - '

# %%
messages = re.split(pattren , data)

# %%
len(messages)
# Out:
# 5593

# %%
dates = re.findall(pattren, data)
dates
# Out:
# ['6/9/23, 1:23\u202fPM - ',
#  '6/9/23, 1:23\u202fPM - ',
#  '11/22/23, 8:11\u202fAM - ',
#  '11/22/23, 8:16\u202fAM - ',
#  '11/22/23, 9:51\u202fPM - ',
#  '11/22/23, 9:55\u202fPM - ',
#  '11/22/23, 9:56\u202fPM - ',
#  '11/22/23, 9:57\u202fPM - ',
#  '11/22/23, 9:57\u202fPM - ',
#  '11/22/23, 9:58\u202fPM - ',
#  '11/22/23, 9:59\u202fPM - ',
#  '11/22/23, 10:49\u202fPM - ',
#  '11/22/23, 10:52\u202fPM - ',
#  '11/22/23, 10:53\u202fPM - ',
#  '11/22/23, 10:53\u202fPM - ',
#  '11/22/23, 10:54\u202fPM - ',
#  '11/22/23, 10:55\u202fPM - ',
#  '11/24/23, 6:10\u202fPM - ',
#  '11/27/23, 10:56\u202fAM - ',
#  '11/28/23, 11:05\u202fPM - ',
#  '11/28/23, 11:12\u202fPM - ',
#  '11/28/23, 11:12\u202fPM - ',
#  '11/28/23, 11:13\u202fPM - ',
#  '11/28/23, 11:13\u202fPM - ',
#  '11/28/23, 11:13\u202fPM - ',
#  '11/28/23, 11:13\u202fPM - ',
#  '11/28/23, 11:14\u202fPM - ',
#  '11/28/23, 11:14\u202fPM - ',
#  '11/28/23, 11:14\u202fPM - ',
#  '11/28/23, 11:14\u202fPM - ',
# ...

# %%
len(dates)
# Out:
# 5592

# %%
dates
# Out:
# ['6/9/23, 1:23\u202fPM - ',
#  '6/9/23, 1:23\u202fPM - ',
#  '11/22/23, 8:11\u202fAM - ',
#  '11/22/23, 8:16\u202fAM - ',
#  '11/22/23, 9:51\u202fPM - ',
#  '11/22/23, 9:55\u202fPM - ',
#  '11/22/23, 9:56\u202fPM - ',
#  '11/22/23, 9:57\u202fPM - ',
#  '11/22/23, 9:57\u202fPM - ',
#  '11/22/23, 9:58\u202fPM - ',
#  '11/22/23, 9:59\u202fPM - ',
#  '11/22/23, 10:49\u202fPM - ',
#  '11/22/23, 10:52\u202fPM - ',
#  '11/22/23, 10:53\u202fPM - ',
#  '11/22/23, 10:53\u202fPM - ',
#  '11/22/23, 10:54\u202fPM - ',
#  '11/22/23, 10:55\u202fPM - ',
#  '11/24/23, 6:10\u202fPM - ',
#  '11/27/23, 10:56\u202fAM - ',
#  '11/28/23, 11:05\u202fPM - ',
#  '11/28/23, 11:12\u202fPM - ',
#  '11/28/23, 11:12\u202fPM - ',
#  '11/28/23, 11:13\u202fPM - ',
#  '11/28/23, 11:13\u202fPM - ',
#  '11/28/23, 11:13\u202fPM - ',
#  '11/28/23, 11:13\u202fPM - ',
#  '11/28/23, 11:14\u202fPM - ',
#  '11/28/23, 11:14\u202fPM - ',
#  '11/28/23, 11:14\u202fPM - ',
#  '11/28/23, 11:14\u202fPM - ',
# ...

# %%
messages = messages[:len(dates)]
len(messages)
# Out:
# 5592

# %%
df = pd.DataFrame({'user_message':messages , 'message_date':dates})
# convert message_date type
df['message_date'] = pd.to_datetime(df['message_date'] , format='%m/%d/%y, %I:%M %p - ')

df.rename(columns={'message_date': 'date'} , inplace=True)

df.head()
# Out:
#                                         user_message                date
# 0                                                    2023-06-09 13:23:00
# 1  Abdul rashed created group "CS Squad Fall 21 t... 2023-06-09 13:23:00
# 2                                   You were added\n 2023-11-22 08:11:00
# 3                   Faheem ❤️❤️cs: <Media omitted>\n 2023-11-22 08:16:00
# 4                                      G R: Oiii🥹😆\n 2023-11-22 21:51:00

# %%
df1 = pd.DataFrame({'user_message':messages , 'message_date':dates})
# convert message_date type 
df1['message_date'] = pd.to_datetime(df1['message_date'] , format='%m/%d/%y, %I:%M %p - ')

df1.rename(columns={'message_date': 'date'} , inplace=True)

df1.head()
# Out:
#                                         user_message                date
# 0                                                    2023-06-09 13:23:00
# 1  Abdul rashed created group "CS Squad Fall 21 t... 2023-06-09 13:23:00
# 2                                   You were added\n 2023-11-22 08:11:00
# 3                   Faheem ❤️❤️cs: <Media omitted>\n 2023-11-22 08:16:00
# 4                                      G R: Oiii🥹😆\n 2023-11-22 21:51:00

# %%
df.shape
# Out:
# (5592, 2)

# %%
# seprate the user and messages
users = []
messagess = []
for message in df['user_message']:
    entry = re.split('([\w\W]+?):\s' , message)
    if entry[1:]:#user name 
        users.append(entry[1])
        messagess.append(entry[2])
    else:
        users.append('group_notification')
        messagess.append(entry[0])

df['user'] = users
df['messsage'] = messagess
df.drop(columns=['user_message'] , inplace=True)

# %%
df.head()
# Out:
#                  date                user  \
# 0 2023-06-09 13:23:00  group_notification
# 1 2023-06-09 13:23:00  group_notification
# 2 2023-11-22 08:11:00  group_notification
# 3 2023-11-22 08:16:00       Faheem ❤️❤️cs
# 4 2023-11-22 21:51:00                 G R
#
#                                             messsage
# 0
# 1  Abdul rashed created group "CS Squad Fall 21 t...
# 2                                   You were added\n
# 3                                  <Media omitted>\n
# 4                                           Oiii🥹😆\n

# %%
# seprate the user and messages
users = []
messagess = []
for message in df1['user_message']:
    entry = re.split('([\w\W]+?):\s' , message)
    if entry[1:]:#user name 
        users.append(entry[1])
        messagess.append(entry[2])
    else:
        users.append('group_notification')
        messagess.append(entry[0])

# %%
for message in df1['user_message']:
     print(message)
# Out:
# Abdul rashed created group "CS Squad Fall 21 to 25"
#
# You were added
#
# Faheem ❤️❤️cs: <Media omitted>
#
# G R: Oiii🥹😆
#
# ghiasuduin124: Assalamu alaikum
# Our Uni football team is going to be Registered by PFF.
# For that purpose I want to fill out team performa and It requires some Information.
# And Our trials will be held in dring stadium Bwp as per instructions of Sir Asif Sports Director CUVAS.
# Interested students contact me as soon as possible
#
# ghiasuduin124: Jo bhi interested ha mujy sy contact kry university ki tarf sy complete kit mly gi or sports facilities bhi include hain
#
# Muhammad Raza: Not interested
#
# ghiasuduin124: You're not good enough to participate
#
# Muhammad Raza: cricket ka bata
#
# Rizwan Rajpot CS: Football ly aa chat 😀
#
# Rizwan Rajpot CS: Paper 2 bjy hy
#
# Maratib CS Uni: Life ma Kabhi Goal 🥍🥅 kia ha Gia's bhai apne?
#
# Hasnain Cs Uni 2 Do it: Subha 2 bjye ho jaye ga
#
# Maratib CS Uni: Good 👍😊
#
# Saad Javed Cs Uni: 🤺⛹️‍♂️
#
# ...

# %%
df
# Out:
#                     date                user  \
# 0    2023-06-09 13:23:00  group_notification
# 1    2023-06-09 13:23:00  group_notification
# 2    2023-11-22 08:11:00  group_notification
# 3    2023-11-22 08:16:00       Faheem ❤️❤️cs
# 4    2023-11-22 21:51:00                 G R
# ...                  ...                 ...
# 5587 2024-08-14 08:19:00       Faizan CS Uni
# 5588 2024-08-14 08:20:00         Rooshii Jan
# 5589 2024-08-14 08:21:00       Faizan CS Uni
# 5590 2024-08-14 08:21:00         Rooshii Jan
# 5591 2024-08-14 17:54:00  group_notification
#
#                                                messsage
# 0
# 1     Abdul rashed created group "CS Squad Fall 21 t...
# 2                                      You were added\n
# 3                                     <Media omitted>\n
# 4                                              Oiii🥹😆\n
# ...                                                 ...
# 5587  @923284280964 VPN laga kr Azadi k status laga ...
# ...

# %%
df['year'] = df['date'].dt.year

# %%
df.head()
# Out:
#                  date                user  \
# 0 2023-06-09 13:23:00  group_notification
# 1 2023-06-09 13:23:00  group_notification
# 2 2023-11-22 08:11:00  group_notification
# 3 2023-11-22 08:16:00       Faheem ❤️❤️cs
# 4 2023-11-22 21:51:00                 G R
#
#                                             messsage  year
# 0                                                     2023
# 1  Abdul rashed created group "CS Squad Fall 21 t...  2023
# 2                                   You were added\n  2023
# 3                                  <Media omitted>\n  2023
# 4                                           Oiii🥹😆\n  2023

# %%
df['month_num'] = df['date'].dt.month

# %%
df['month'] = df['date'].dt.month_name()

# %%
df['day'] = df['date'].dt.day

# %%
df['hour'] = df['date'].dt.hour

# %%
df['minute'] = df['date'].dt.minute

# %%
timeline = df.groupby(['year' , 'month_num' , 'month']).count()['messsage'].reset_index()

# %%
timeline
# Out:
#     year  month_num     month  messsage
# 0   2023          6      June         2
# 1   2023         11  November       149
# 2   2023         12  December       678
# 3   2024          1   January       856
# 4   2024          2  February       246
# 5   2024          3     March       629
# 6   2024          4     April      1235
# 7   2024          5       May       642
# 8   2024          6      June       651
# 9   2024          7      July       404
# 10  2024          8    August       100

# %%
time = []
for i in range(timeline.shape[0]):
    time.append(timeline['month'][i]+ " " + str(timeline['year'][i]))

# %%
timeline['time'] = time

# %%
timeline
# Out:
#     year  month_num          month  messsage           time
# 0   2023          6      June 2023         2      June 2023
# 1   2023         11  November 2023       149  November 2023
# 2   2023         12  December 2023       678  December 2023
# 3   2024          1   January 2024       856   January 2024
# 4   2024          2  February 2024       246  February 2024
# 5   2024          3     March 2024       629     March 2024
# 6   2024          4     April 2024      1235     April 2024
# 7   2024          5       May 2024       642       May 2024
# 8   2024          6      June 2024       651      June 2024
# 9   2024          7      July 2024       404      July 2024
# 10  2024          8    August 2024       100    August 2024

# %%
plt.plot(timeline['time'] , timeline['messsage'])
plt.xticks(rotation='vertical')
plt.show()

# %%
df.head()
# Out:
#                  date                user  \
# 0 2023-06-09 13:23:00  group_notification
# 1 2023-06-09 13:23:00  group_notification
# 2 2023-11-22 08:11:00  group_notification
# 3 2023-11-22 08:16:00       Faheem ❤️❤️cs
# 4 2023-11-22 21:51:00                 G R
#
#                                             messsage  year     month  day  \
# 0                                                     2023      June    9
# 1  Abdul rashed created group "CS Squad Fall 21 t...  2023      June    9
# 2                                   You were added\n  2023  November   22
# 3                                  <Media omitted>\n  2023  November   22
# 4                                           Oiii🥹😆\n  2023  November   22
#
#    hour  minute
# 0    13      23
# 1    13      23
# 2     8      11
# 3     8      16
# 4    21      51

# %%
df[df['user'] == 'Faheem ❤️❤️cs']
# Out:
#                     date           user  \
# 3    2023-11-22 08:16:00  Faheem ❤️❤️cs
# 774  2023-12-26 16:06:00  Faheem ❤️❤️cs
# 776  2023-12-26 16:09:00  Faheem ❤️❤️cs
# 778  2023-12-27 15:37:00  Faheem ❤️❤️cs
# 1089 2024-01-16 20:31:00  Faheem ❤️❤️cs
# 1259 2024-01-17 10:39:00  Faheem ❤️❤️cs
# 1641 2024-01-25 22:00:00  Faheem ❤️❤️cs
# 2081 2024-03-13 08:04:00  Faheem ❤️❤️cs
# 2082 2024-03-13 08:04:00  Faheem ❤️❤️cs
# 2085 2024-03-13 08:21:00  Faheem ❤️❤️cs
# 2276 2024-03-26 12:28:00  Faheem ❤️❤️cs
# 2281 2024-03-26 12:30:00  Faheem ❤️❤️cs
# 2591 2024-04-02 19:50:00  Faheem ❤️❤️cs
# 2641 2024-04-02 19:57:00  Faheem ❤️❤️cs
# 2888 2024-04-05 14:02:00  Faheem ❤️❤️cs
# 2893 2024-04-05 14:02:00  Faheem ❤️❤️cs
# 3204 2024-04-09 20:48:00  Faheem ❤️❤️cs
# 3963 2024-05-17 01:29:00  Faheem ❤️❤️cs
# 4984 2024-06-26 15:43:00  Faheem ❤️❤️cs
# 5478 2024-07-29 11:14:00  Faheem ❤️❤️cs
# 5482 2024-07-29 11:15:00  Faheem ❤️❤️cs
#
# ...

# %%
words = []
for message in df['messsage']:
    words.extend(message.split())

# %%
len(words)
# Out:
# 33284

# %%
df[df['messsage'] == '<Media omitted>\n']
# Out:
#                     date                          user           messsage  \
# 3    2023-11-22 08:16:00                 Faheem ❤️❤️cs  <Media omitted>\n
# 19   2023-11-28 23:05:00               +92 323 5078996  <Media omitted>\n
# 40   2023-11-28 23:19:00                 Faizan CS Uni  <Media omitted>\n
# 41   2023-11-28 23:20:00                  Abdul rashed  <Media omitted>\n
# 51   2023-11-28 23:25:00                  Abdul rashed  <Media omitted>\n
# ...                  ...                           ...                ...
# 5545 2024-08-13 03:52:00                  Awais Uni CS  <Media omitted>\n
# 5549 2024-08-13 07:18:00  Imran Fareed CS Cuvas Jampur  <Media omitted>\n
# 5574 2024-08-13 21:17:00                 STM(R)🥰 Sidra  <Media omitted>\n
# 5583 2024-08-14 08:11:00                 Faizan CS Uni  <Media omitted>\n
# 5584 2024-08-14 08:11:00                   Rooshii Jan  <Media omitted>\n
#
#       year     month  day  hour  minute
# ...

# %%
pip install urlextract
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from urlextract import URLExtract
extractor = URLExtract()

urls = extractor.find_urls("www.google.com , www.eisakhan.com  , www.youtube.com")
urls
# Out:
# ['www.google.com', 'www.eisakhan.com', 'www.youtube.com']

# %%
links = []

for message in df['messsage']:
    
    links.extend(extractor.find_urls(message))

# %%
len(links)
# Out:
# 32

# %%
# most message in group user
# most busy users
x = df['user'].value_counts().head()

# %%
import matplotlib.pyplot as plt

# %%
x.values
# Out:
# array([1274,  819,  560,  353,  321], dtype=int64)

# %%
x.index
# Out:
# Index(['Abdul rashed', 'Rooshii Jan', 'Maratib CS Uni',
#        'Imran Fareed CS Cuvas Jampur', 'Eisa Baloch'],
#       dtype='object')

# %%
name = x.index
count = x.values

# %%
plt.bar(name, count)
plt.xticks(rotation='vertical')
plt.show()

# %%
round((df['user'].value_counts()/df.shape[0])*100 , 2).reset_index().rename(columns={'index':'name' , 'user':'percent'})
# Out:
#                             name  percent
# 0                   Abdul rashed    22.78
# 1                    Rooshii Jan    14.65
# 2                 Maratib CS Uni    10.01
# 3   Imran Fareed CS Cuvas Jampur     6.31
# 4                    Eisa Baloch     5.74
# 5                  Faizan CS Uni     4.63
# 6                   Awais Uni CS     4.36
# 7                   kashif bahii     3.93
# 8                   Amir chandia     3.76
# 9                Mubashir Uni CS     3.04
# 10                 Waqas C's Uni     2.66
# 11                   Zain Uni CS     2.45
# 12                 ghiasuduin124     2.00
# 13            group_notification     1.56
# 14                     Cs Junaid     1.54
# 15        Hasnain Cs Uni 2 Do it     1.31
# 16               Zohaib Cuvas BS     0.95
# 17                  Ahaan Ismail     0.89
# 18               Shahrooz Faheem     0.82
# 19                    Naima Khan     0.73
# 20                           G R     0.63
# ...

# %%
temp = df[df['user']!= 'group_notification']
temp = temp[temp['messsage'] != '<Media omitted>\n']

# %%
words = []
for message in temp['messsage']:
    words.extend(message.split())

# %%
from collections import Counter
pd.DataFrame(Counter(words).most_common(20))
# Out:
#       0    1
# 0    ha  581
# 1    to  319
# 2    ka  313
# 3    ko  272
# 4    ho  271
# 5    kr  248
# 6    na  247
# 7    ap  208
# 8     k  194
# 9    ma  182
# 10   ki  176
# 11   hy  174
# 12   ga  147
# 13  nai  139
# 14    a  139
# 15  kia  135
# 16   Hy  129
# 17    h  109
# 18  the  108
# 19   ke  105

# %%
pip install emoji
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import emoji

# %%
emojis = []
for message in df['messsage']:
    emojis.extend([c for c in message if c in emoji.EMOJI_DATA])

# %%
emojis = []
for message in df['messsage']:
    emojis.extend([c for c in message if c in emoji.EMOJI_DATA])

# %%
pd.DataFrame(Counter(emojis).most_common(len(Counter(emojis))))
# Out:
#      0    1
# 0    😂  462
# 1    😄  242
# 2    🤣  235
# 3    😆   90
# 4    🏻   78
# ..  ..  ...
# 193  🍆    1
# 194  🥕    1
# 195  🫑    1
# 196  🫒    1
# 197  🤷    1
#
# [198 rows x 2 columns]

# %%
df['only_date'] = df['date'].dt.date

# %%
daily_timeline = df.groupby('only_date').count()['messsage'].reset_index()

# %%
plt
plt.plot(daily_timeline['only_date'] , daily_timeline['messsage'])

# %%
df['day_name'] = df['date'].dt.day_name()

# %%
df['day_name'].value_counts()
# Out:
# Tuesday      1136
# Wednesday     973
# Friday        911
# Saturday      854
# Thursday      831
# Sunday        580
# Monday        307
# Name: day_name, dtype: int64

# %%
df['month'].value_counts()
# Out:
# April       1235
# January      856
# December     678
# June         653
# May          642
# March        629
# July         404
# February     246
# November     149
# August       100
# Name: month, dtype: int64

# %%
df.head()
# Out:
#                  date                user  \
# 0 2023-06-09 13:23:00  group_notification
# 1 2023-06-09 13:23:00  group_notification
# 2 2023-11-22 08:11:00  group_notification
# 3 2023-11-22 08:16:00       Faheem ❤️❤️cs
# 4 2023-11-22 21:51:00                 G R
#
#                                             messsage  year     month  day  \
# 0                                                     2023      June    9
# 1  Abdul rashed created group "CS Squad Fall 21 t...  2023      June    9
# 2                                   You were added\n  2023  November   22
# 3                                  <Media omitted>\n  2023  November   22
# 4                                           Oiii🥹😆\n  2023  November   22
#
#    hour  minute  month_num   only_date   day_name
# 0    13      23          6  2023-06-09     Friday
# 1    13      23          6  2023-06-09     Friday
# 2     8      11         11  2023-11-22  Wednesday
# 3     8      16         11  2023-11-22  Wednesday
# ...

# %%
period = []
for hour in df[['day_name' , 'hour']]['hour']:
    if hour == 23:
        period.append(str(hour) + "-" + str('00'))
    elif hour ==0:
        period.append(str('00') + "-" + str(hour+1))
    else:
        period.append(str(hour) + "-" + str(hour+1))

# %%
df['period'] = period

# %%
df.sample(5)
# Out:
#                     date            user  \
# 4299 2024-05-29 20:28:00  Maratib CS Uni
# 4441 2024-06-01 15:12:00   Waqas C's Uni
# 4449 2024-06-01 16:14:00   Waqas C's Uni
# 3309 2024-04-09 23:58:00    Abdul rashed
# 4646 2024-06-12 10:27:00   Faizan CS Uni
#
#                                                messsage  year  month  day  \
# 4299  Kmall ha yrr HM bache ha hme NI pta garmi se k...  2024    May   29
# 4441     Name mention kia kra  asa kisi pa bt ni krni\n  2024   June    1
# 4449                                  <Media omitted>\n  2024   June    1
# 3309   Kyu k us time jb eidi ka kaha tha tum bajgh gy\n  2024  April    9
# 4646                                What type of Boss\n  2024   June   12
#
#       hour  minute  month_num   only_date   day_name period
# 4299    20      28          5  2024-05-29  Wednesday  20-21
# 4441    15      12          6  2024-06-01   Saturday  15-16
# 4449    16      14          6  2024-06-01   Saturday  16-17
# ...

# %%
import seaborn as sns
plt.figure(figsize=(20,6))
sns.heatmap(df.pivot_table(index='day_name' ,columns='period' , values='messsage' , aggfunc='count').fillna(0))
plt.yticks(rotation='horizontal')
plt.show()
